# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import copy
import pymc as pm
import arviz as az
import dill
import os
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
from thesis_tools.utils.data import *
from thesis_tools.models.frequentist import *
from thesis_tools.models.bayesian_univariate_time_series import *

# %%
df = read_panel_data(observations_threshold=0)

# %%
df['group'].unique()
# Out:
# array(['Alps', 'Asian Islands', 'Australia', 'Brazil', 'British Islands',
#        'Canada', 'China', 'France', 'Germany', 'India', 'Israel + Turkey',
#        'Italy', 'Japan', 'Russia', 'Scandinavia', 'South Korea',
#        'Southeast Asia', 'U.S.'], dtype=object)

# %%
# filter only on the group of interest
temp = df[df['group'] == 'U.S.']
# only certain columns are needed
temp = temp[['group', 'year', 'N_net_worth',
       'log_change_gdp_pc', 'log_change_CAC40', 'log_change_DAX',
       'log_change_FTSE100', 'log_change_MOEX', 'log_change_MSCI',
       'log_change_NIFTY', 'log_change_OMX40', 'log_change_SPX',
       'log_change_SSE']]
temp
# Out:
#     group  year  N_net_worth  log_change_gdp_pc  log_change_CAC40  \
# 401  U.S.  2001          182                NaN               NaN
# 402  U.S.  2002          176           0.023004         -0.295940
# 403  U.S.  2003          165           0.038527         -0.417880
# 404  U.S.  2004          211           0.055037          0.213867
# 405  U.S.  2005          261           0.055899          0.072926
# 406  U.S.  2006          292           0.048195          0.234501
# 407  U.S.  2007          329           0.037062          0.125268
# 408  U.S.  2008          382           0.010760         -0.141199
# 409  U.S.  2009          334          -0.028720         -0.493170
# 410  U.S.  2010          403           0.030378          0.229060
# 411  U.S.  2011          413           0.028676          0.068727
# 412  U.S.  2012          424           0.033748         -0.194185
# 413  U.S.  2013          442           0.028681          0.123622
# 414  U.S.  2014          492           0.033813          0.109784
# 415  U.S.  2015          535           0.029297          0.100091
# 416  U.S.  2016          541           0.019263         -0.041515
# 417  U.S.  2017          565           0.034663          0.072448
# 418  U.S.  2018          586           0.047520          0.143544
# 419  U.S.  2019          607           0.035912         -0.093476
# 420  U.S.  2020          615          -0.024747          0.150970
# 421  U.S.  2021          724           0.100135         -0.072698
# 422  U.S.  2022          735           0.083435          0.259543
#
#      log_change_DAX  log_change_FTSE100  log_change_MOEX  log_change_MSCI  \
# 401             NaN                 NaN              NaN              NaN
# 402       -0.285476           -0.198295              NaN        -0.254430
# 403       -0.619920           -0.370023              NaN        -0.231568
# 404        0.390027            0.207644              NaN         0.315883
# 405        0.047221            0.099971              NaN         0.092312
# 406        0.287861            0.171528              NaN         0.115666
# 407        0.179399            0.074065              NaN         0.155394
# 408        0.009184           -0.053528              NaN        -0.019322
# 409       -0.457010           -0.348498              NaN        -0.572140
# 410        0.256841            0.223427              NaN         0.288665
# 411        0.232583            0.122203              NaN         0.173574
# 412       -0.091457           -0.031417              NaN        -0.044530
# 413        0.185588            0.099638              NaN         0.106475
# 414        0.179663            0.036534              NaN         0.120665
# 415        0.139002            0.036047         0.125021         0.048239
# 416       -0.087523           -0.103826         0.079999        -0.071210
# 417        0.163223            0.154347         0.216957         0.144743
# 418        0.134007            0.059391         0.032217         0.184581
# 419       -0.165911           -0.077916         0.096148        -0.067579
# 420        0.150052            0.044506         0.199146         0.143337
# 421        0.034143           -0.128493         0.063111         0.127789
# 422        0.141276            0.152678         0.074453         0.136996
#
#      log_change_NIFTY  log_change_OMX40  log_change_SPX  log_change_SSE
# 401               NaN               NaN             NaN             NaN
# 402               NaN               NaN       -0.189500       -0.325531
# 403               NaN               NaN       -0.278230        0.005449
# 404               NaN               NaN        0.279053        0.058851
# 405               NaN               NaN        0.043373       -0.288708
# 406               NaN               NaN        0.080332        0.054076
# 407               NaN               NaN        0.116498        0.795167
# 408               NaN               NaN       -0.042388        0.453096
# 409         -0.580574               NaN       -0.512338       -0.789358
# 410          0.529582               NaN        0.262575        0.406572
# 411          0.120255               NaN        0.180361       -0.068746
# 412         -0.057306               NaN        0.020235       -0.196599
# 413          0.149020               NaN        0.132339        0.039685
# 414          0.009032               NaN        0.173863       -0.159823
# 415          0.369197               NaN        0.112572        0.456831
# 416         -0.152422         -0.022897       -0.027827       -0.159302
# 417          0.123911          0.014196        0.160868        0.143226
# 418          0.253158          0.065444        0.214407        0.096964
# 419         -0.018003         -0.079627       -0.043318       -0.297712
# 420          0.099335          0.147365        0.176325        0.141198
# 421          0.130867          0.145027        0.141080        0.157156
# 422          0.240397          0.121456        0.195353       -0.035544

# %%
# go through all files in the path ../../Stored_Models/bayesian_univariate_time_series/
# and check the number of divergences
# if there are divergences, print the name of the model
divergence_dict = {}
path = "../../Stored_Models/bayesian_univariate_time_series/"
for file in os.listdir(path):
    temp_model = dill.load(open(path + file, "rb"))
    temp_trace = temp_model.get_trace()
    n_divergences = sum(temp_trace['sample_stats']['diverging'].values.flatten())
    divergence_dict[file] = n_divergences
divergence_df = pd.DataFrame(divergence_dict.items(), columns=['model', 'n_divergences'])
divergence_df = divergence_df.sort_values(by='n_divergences', ascending=False)
divergence_df.set_index('model', inplace=True)

# %%
divergence_df
# Out:
#                                                     n_divergences
# model
# British Islands_Pareto_2007_2020_constant_log_c...           1589
# Asian Islands_Pareto_2010_2021_constant_log_cha...           1403
# Japan_Pareto_2014_2021_constant_log_change_gdp_...           1258
# Canada_Pareto_2010_2021_constant_log_change_gdp...           1165
# Canada_Pareto_2010_2019_constant_log_change_gdp...           1107
# ...                                                           ...
# India_GeneralisedPareto_2009_2021_constant_log_...             31
# U.S._GeneralisedPareto_2005_2019_constant_log_c...             29
# U.S._GeneralisedPareto_2005_2020_constant_log_c...             24
# U.S._Weibull_2005_2021_constant_log_change_gdp_...             23
# U.S._Weibull_2005_2020_constant_log_change_gdp_...             18
#
# [211 rows x 1 columns]

# %%
# Notes:
# Alps: 20 obs from 2013 onwards -> train until 2021, predict 2022, use const, gdp and MSCI world
# Asian Islands: 25 obs from 2010 onwards -> train until 2019 & 2020 & 2021, predict 2020 & 2021 & 2022, use const, gdp and MSCI world
# Australia: 20 obs from 2013 onwards -> train until 2021, predict 2022, use const, gdp and MSCI world
# Brazil: 30 obs from 2011 onwards -> train until 2020 & 2021, predict 2021 & 2022, use const, gdp and MSCI world
# British Islands: 25 obs from 2007 onwards -> train until 2019 & 2020 & 2021, predict 2020 & 2021 & 2022, use const, gdp and FTSE100
# Canada: 24 obs from 2010 onwards -> train until 2019 & 2020 & 2021, predict 2020 & 2021 & 2022, use const, gdp and MSCI world
# China: 30 obs from 2007 onwards -> train until 2019 & 2020 & 2021, predict 2020 & 2021 & 2022, use const, gdp and SSE
# France: 25 obs from 2013 onwards -> train until 2021, predict 2022, use const, gdp and CAC40
# Germany: 40 obs from 2005 onwards -> train until 2019 & 2020 & 2021, predict 2020 & 2021 & 2022, use const, gdp and DAX
# India: 40 obs from 2009 onwards -> train until 2019 & 2020 & 2021, predict 2020 & 2021 & 2022, use const, gdp and NIFTY
# Israel + Turkey: 30 obs from 2010 onwards -> train until 2019 & 2020 & 2021, predict 2020 & 2021 & 2022, use const, gdp and MSCI world
# Italy: 30 obs from 2014 onwards -> train until 2021, predict 2022, use const, gdp and MSCI world
# Japan: 25 obs from 2014 onwards -> train until 2021, predict 2022, use const, gdp and MSCI world
# Russia: 45 obs from 2007 onwards -> train until 2019 & 2020 & 2021, predict 2020 & 2021 & 2022, use const, gdp and MOEX (only for 2015 onwards)
# Scandinavia: only from 2016 onwards due to OMX40 -> train until 2021, predict 2022, use const, gdp and OMX40
# South Korea: 30 obs from 2015 onwards -> train until 2021, predict 2022, use const, gdp and MSCI world
# Southeast Asia: 30 obs from 2013 onwards -> train until 2021, predict 2022, use const, gdp and MSCI world
# U.S.: train until 2019, 2020 and 2021, predict 2020, 2021 and 2022, use const, gdp and SPX

# %%
setups = [
    {
        "group": "Alps",
        "start_year": 2013,
        "end_year": [2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_MSCI"]
    },
    {
        "group": "Asian Islands",
        "start_year": 2010,
        "end_year": [2019, 2020, 2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_MSCI"]
    },
    {
        "group": "Australia",
        "start_year": 2013,
        "end_year": [2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_MSCI"]
    },
    {
        "group": "Brazil",
        "start_year": 2011,
        "end_year": [2020, 2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_MSCI"]
    },
    {
        "group": "British Islands",
        "start_year": 2007,
        "end_year": [2019, 2020, 2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_FTSE100"]
    },
    {
        "group": "Canada",
        "start_year": 2010,
        "end_year": [2019, 2020, 2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_MSCI"]
    },
    {
        "group": "China",
        "start_year": 2007,
        "end_year": [2019, 2020, 2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_SSE"]
    },
    {
        "group": "France",
        "start_year": 2013,
        "end_year": [2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_CAC40"]
    },
    {
        "group": "Germany",
        "start_year": 2005,
        "end_year": [2019, 2020, 2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_DAX"]
    },
    {
        "group": "India",
        "start_year": 2009,
        "end_year": [2019, 2020, 2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_NIFTY"]
    },
    {
        "group": "Israel + Turkey",
        "start_year": 2010,
        "end_year": [2019, 2020, 2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_MSCI"]
    },
    {
        "group": "Italy",
        "start_year": 2014,
        "end_year": [2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_MSCI"]
    },
    {
        "group": "Japan",
        "start_year": 2014,
        "end_year": [2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_MSCI"]
    },
    {
        "group": "Russia",
        "start_year": 2015,
        "end_year": [2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_MOEX"]
    },
    {
        "group": "Scandinavia",
        "start_year": 2016,
        "end_year": [2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_OMX40"]
    },
    {
        "group": "South Korea",
        "start_year": 2015,
        "end_year": [2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_MSCI"]
    },
    {
        "group": "Southeast Asia",
        "start_year": 2013,
        "end_year": [2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_MSCI"]
    },
    {
        "group": "U.S.",
        "start_year": 2005,
        "end_year": [2019, 2020, 2021],
        "covariates": ["constant", "log_change_gdp_pc", "log_change_SPX"]
    }
]

# %%
def train_or_retrieve_model(
    panel_df:pd.DataFrame, 
    group:str, 
    covariates:list[str],
    start_year:int,
    end_year:int, 
    model_type:str, 
    retrain_if_saved=False
):
    model_name = f"{group}_{model_type}_{start_year}_{end_year}"
    for covariate in covariates:
        model_name += f"_{covariate}"
    model_path = f"../../Stored_Models/bayesian_univariate_time_series/{model_name}.pkl"
    if os.path.exists(model_path) and not retrain_if_saved:
        with open(model_path, "rb") as f:
            model = dill.load(f)
    else:
        data = copy.deepcopy(panel_df[panel_df['group'] == group])
        data = data[data['year'] >= start_year]
        if model_type == 'Pareto':
            model = Univariate_Pareto_TimeSeries(
                panel_df=data,
                train_until=end_year,
                X_columns=covariates
            )
        elif model_type == 'Weibull':
            model = Univariate_Weibull_TimeSeries(
                panel_df=data,
                train_until=end_year,
                X_columns=covariates
            )
        elif model_type == 'GeneralisedPareto':
            model = Univariate_GeneralisedPareto_TimeSeries(
                panel_df=data,
                train_until=end_year,
                X_columns=covariates
            )
        model.fit(target_accept=0.99, nuts_sampler='pymc')
        with open(model_path, "wb") as f:
            dill.dump(model, f)
    return model

# %%
i = 0
for setup in setups:
    model_types = ['Pareto', 'Weibull', 'GeneralisedPareto']
    for model_type in model_types:
        for end_year in setup['end_year']:
            covariate_options = [setup['covariates'][0:2], setup['covariates']]
            for option in covariate_options:
                i += 1
                model_name = f"{setup['group']}_{model_type}_{setup['start_year']}_{end_year}"
                for covariate in option:
                    model_name += f"_{covariate}"
                model_name += ".pkl"
                print(f"Training model {i}: {model_name}")
                n_divergences = divergence_df.loc[model_name]['n_divergences']
                if n_divergences > 250 and model_type != 'Pareto':
                    retrain_if_saved = True
                else:
                    retrain_if_saved = False
                train_or_retrieve_model(
                    panel_df=df,
                    group=setup['group'],
                    covariates=option,
                    start_year=setup['start_year'],
                    end_year=end_year,
                    model_type=model_type,
                    retrain_if_saved=retrain_if_saved
                )
# Out:
# Training model 1: Alps_Pareto_2013_2021_constant_log_change_gdp_pc.pkl
# Training model 2: Alps_Pareto_2013_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 3: Alps_Weibull_2013_2021_constant_log_change_gdp_pc.pkl
# Training model 4: Alps_Weibull_2013_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 5: Alps_GeneralisedPareto_2013_2021_constant_log_change_gdp_pc.pkl
# Training model 6: Alps_GeneralisedPareto_2013_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 7: Asian Islands_Pareto_2010_2019_constant_log_change_gdp_pc.pkl
# Training model 8: Asian Islands_Pareto_2010_2019_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 9: Asian Islands_Pareto_2010_2020_constant_log_change_gdp_pc.pkl
# Training model 10: Asian Islands_Pareto_2010_2020_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 11: Asian Islands_Pareto_2010_2021_constant_log_change_gdp_pc.pkl
# Training model 12: Asian Islands_Pareto_2010_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 13: Asian Islands_Weibull_2010_2019_constant_log_change_gdp_pc.pkl
# Training model 14: Asian Islands_Weibull_2010_2019_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 15: Asian Islands_Weibull_2010_2020_constant_log_change_gdp_pc.pkl
# Training model 16: Asian Islands_Weibull_2010_2020_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 17: Asian Islands_Weibull_2010_2021_constant_log_change_gdp_pc.pkl
# Training model 18: Asian Islands_Weibull_2010_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 19: Asian Islands_GeneralisedPareto_2010_2019_constant_log_change_gdp_pc.pkl
# Training model 20: Asian Islands_GeneralisedPareto_2010_2019_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 21: Asian Islands_GeneralisedPareto_2010_2020_constant_log_change_gdp_pc.pkl
# Training model 22: Asian Islands_GeneralisedPareto_2010_2020_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 23: Asian Islands_GeneralisedPareto_2010_2021_constant_log_change_gdp_pc.pkl
# Training model 24: Asian Islands_GeneralisedPareto_2010_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 25: Australia_Pareto_2013_2021_constant_log_change_gdp_pc.pkl
# Training model 26: Australia_Pareto_2013_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 27: Australia_Weibull_2013_2021_constant_log_change_gdp_pc.pkl
# Training model 28: Australia_Weibull_2013_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 29: Australia_GeneralisedPareto_2013_2021_constant_log_change_gdp_pc.pkl
# Training model 30: Australia_GeneralisedPareto_2013_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 31: Brazil_Pareto_2011_2020_constant_log_change_gdp_pc.pkl
# Training model 32: Brazil_Pareto_2011_2020_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 33: Brazil_Pareto_2011_2021_constant_log_change_gdp_pc.pkl
# Training model 34: Brazil_Pareto_2011_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 35: Brazil_Weibull_2011_2020_constant_log_change_gdp_pc.pkl
# Training model 36: Brazil_Weibull_2011_2020_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 37: Brazil_Weibull_2011_2021_constant_log_change_gdp_pc.pkl
# Training model 38: Brazil_Weibull_2011_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 39: Brazil_GeneralisedPareto_2011_2020_constant_log_change_gdp_pc.pkl
# Training model 40: Brazil_GeneralisedPareto_2011_2020_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 41: Brazil_GeneralisedPareto_2011_2021_constant_log_change_gdp_pc.pkl
# Training model 42: Brazil_GeneralisedPareto_2011_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 43: British Islands_Pareto_2007_2019_constant_log_change_gdp_pc.pkl
# Training model 44: British Islands_Pareto_2007_2019_constant_log_change_gdp_pc_log_change_FTSE100.pkl
# Training model 45: British Islands_Pareto_2007_2020_constant_log_change_gdp_pc.pkl
# Training model 46: British Islands_Pareto_2007_2020_constant_log_change_gdp_pc_log_change_FTSE100.pkl
# Training model 47: British Islands_Pareto_2007_2021_constant_log_change_gdp_pc.pkl
# Training model 48: British Islands_Pareto_2007_2021_constant_log_change_gdp_pc_log_change_FTSE100.pkl
# Training model 49: British Islands_Weibull_2007_2019_constant_log_change_gdp_pc.pkl
# Training model 50: British Islands_Weibull_2007_2019_constant_log_change_gdp_pc_log_change_FTSE100.pkl
# Training model 51: British Islands_Weibull_2007_2020_constant_log_change_gdp_pc.pkl
# Training model 52: British Islands_Weibull_2007_2020_constant_log_change_gdp_pc_log_change_FTSE100.pkl
# Training model 53: British Islands_Weibull_2007_2021_constant_log_change_gdp_pc.pkl
# Training model 54: British Islands_Weibull_2007_2021_constant_log_change_gdp_pc_log_change_FTSE100.pkl
# Training model 55: British Islands_GeneralisedPareto_2007_2019_constant_log_change_gdp_pc.pkl
# Training model 56: British Islands_GeneralisedPareto_2007_2019_constant_log_change_gdp_pc_log_change_FTSE100.pkl
# Training model 57: British Islands_GeneralisedPareto_2007_2020_constant_log_change_gdp_pc.pkl
# Training model 58: British Islands_GeneralisedPareto_2007_2020_constant_log_change_gdp_pc_log_change_FTSE100.pkl
# Training model 59: British Islands_GeneralisedPareto_2007_2021_constant_log_change_gdp_pc.pkl
# Training model 60: British Islands_GeneralisedPareto_2007_2021_constant_log_change_gdp_pc_log_change_FTSE100.pkl
# Training model 61: Canada_Pareto_2010_2019_constant_log_change_gdp_pc.pkl
# Training model 62: Canada_Pareto_2010_2019_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 63: Canada_Pareto_2010_2020_constant_log_change_gdp_pc.pkl
# Training model 64: Canada_Pareto_2010_2020_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 65: Canada_Pareto_2010_2021_constant_log_change_gdp_pc.pkl
# Training model 66: Canada_Pareto_2010_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 67: Canada_Weibull_2010_2019_constant_log_change_gdp_pc.pkl
# Training model 68: Canada_Weibull_2010_2019_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 69: Canada_Weibull_2010_2020_constant_log_change_gdp_pc.pkl
# Training model 70: Canada_Weibull_2010_2020_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 71: Canada_Weibull_2010_2021_constant_log_change_gdp_pc.pkl
# Training model 72: Canada_Weibull_2010_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 73: Canada_GeneralisedPareto_2010_2019_constant_log_change_gdp_pc.pkl
# Training model 74: Canada_GeneralisedPareto_2010_2019_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 75: Canada_GeneralisedPareto_2010_2020_constant_log_change_gdp_pc.pkl
# Training model 76: Canada_GeneralisedPareto_2010_2020_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 77: Canada_GeneralisedPareto_2010_2021_constant_log_change_gdp_pc.pkl
# Training model 78: Canada_GeneralisedPareto_2010_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 79: China_Pareto_2007_2019_constant_log_change_gdp_pc.pkl
# Training model 80: China_Pareto_2007_2019_constant_log_change_gdp_pc_log_change_SSE.pkl
# Training model 81: China_Pareto_2007_2020_constant_log_change_gdp_pc.pkl
# Training model 82: China_Pareto_2007_2020_constant_log_change_gdp_pc_log_change_SSE.pkl
# Training model 83: China_Pareto_2007_2021_constant_log_change_gdp_pc.pkl
# Training model 84: China_Pareto_2007_2021_constant_log_change_gdp_pc_log_change_SSE.pkl
# Training model 85: China_Weibull_2007_2019_constant_log_change_gdp_pc.pkl
# Training model 86: China_Weibull_2007_2019_constant_log_change_gdp_pc_log_change_SSE.pkl
# Training model 87: China_Weibull_2007_2020_constant_log_change_gdp_pc.pkl
# Training model 88: China_Weibull_2007_2020_constant_log_change_gdp_pc_log_change_SSE.pkl
# Training model 89: China_Weibull_2007_2021_constant_log_change_gdp_pc.pkl
# Training model 90: China_Weibull_2007_2021_constant_log_change_gdp_pc_log_change_SSE.pkl
# Training model 91: China_GeneralisedPareto_2007_2019_constant_log_change_gdp_pc.pkl
# Training model 92: China_GeneralisedPareto_2007_2019_constant_log_change_gdp_pc_log_change_SSE.pkl
# Training model 93: China_GeneralisedPareto_2007_2020_constant_log_change_gdp_pc.pkl
# Training model 94: China_GeneralisedPareto_2007_2020_constant_log_change_gdp_pc_log_change_SSE.pkl
# Training model 95: China_GeneralisedPareto_2007_2021_constant_log_change_gdp_pc.pkl
# Training model 96: China_GeneralisedPareto_2007_2021_constant_log_change_gdp_pc_log_change_SSE.pkl
# Training model 97: France_Pareto_2013_2021_constant_log_change_gdp_pc.pkl
# Training model 98: France_Pareto_2013_2021_constant_log_change_gdp_pc_log_change_CAC40.pkl
# Training model 99: France_Weibull_2013_2021_constant_log_change_gdp_pc.pkl
# Training model 100: France_Weibull_2013_2021_constant_log_change_gdp_pc_log_change_CAC40.pkl
# Training model 101: France_GeneralisedPareto_2013_2021_constant_log_change_gdp_pc.pkl
# Training model 102: France_GeneralisedPareto_2013_2021_constant_log_change_gdp_pc_log_change_CAC40.pkl
# Training model 103: Germany_Pareto_2005_2019_constant_log_change_gdp_pc.pkl
# Training model 104: Germany_Pareto_2005_2019_constant_log_change_gdp_pc_log_change_DAX.pkl
# Training model 105: Germany_Pareto_2005_2020_constant_log_change_gdp_pc.pkl
# Training model 106: Germany_Pareto_2005_2020_constant_log_change_gdp_pc_log_change_DAX.pkl
# Training model 107: Germany_Pareto_2005_2021_constant_log_change_gdp_pc.pkl
# Training model 108: Germany_Pareto_2005_2021_constant_log_change_gdp_pc_log_change_DAX.pkl
# Training model 109: Germany_Weibull_2005_2019_constant_log_change_gdp_pc.pkl
# Training model 110: Germany_Weibull_2005_2019_constant_log_change_gdp_pc_log_change_DAX.pkl
# Training model 111: Germany_Weibull_2005_2020_constant_log_change_gdp_pc.pkl
# Training model 112: Germany_Weibull_2005_2020_constant_log_change_gdp_pc_log_change_DAX.pkl
# Training model 113: Germany_Weibull_2005_2021_constant_log_change_gdp_pc.pkl
# Training model 114: Germany_Weibull_2005_2021_constant_log_change_gdp_pc_log_change_DAX.pkl
# Training model 115: Germany_GeneralisedPareto_2005_2019_constant_log_change_gdp_pc.pkl
# Training model 116: Germany_GeneralisedPareto_2005_2019_constant_log_change_gdp_pc_log_change_DAX.pkl
# Training model 117: Germany_GeneralisedPareto_2005_2020_constant_log_change_gdp_pc.pkl
# Training model 118: Germany_GeneralisedPareto_2005_2020_constant_log_change_gdp_pc_log_change_DAX.pkl
# Training model 119: Germany_GeneralisedPareto_2005_2021_constant_log_change_gdp_pc.pkl
# Training model 120: Germany_GeneralisedPareto_2005_2021_constant_log_change_gdp_pc_log_change_DAX.pkl
# Training model 121: India_Pareto_2009_2019_constant_log_change_gdp_pc.pkl
# Training model 122: India_Pareto_2009_2019_constant_log_change_gdp_pc_log_change_NIFTY.pkl
# Training model 123: India_Pareto_2009_2020_constant_log_change_gdp_pc.pkl
# Training model 124: India_Pareto_2009_2020_constant_log_change_gdp_pc_log_change_NIFTY.pkl
# Training model 125: India_Pareto_2009_2021_constant_log_change_gdp_pc.pkl
# Training model 126: India_Pareto_2009_2021_constant_log_change_gdp_pc_log_change_NIFTY.pkl
# Training model 127: India_Weibull_2009_2019_constant_log_change_gdp_pc.pkl
# Training model 128: India_Weibull_2009_2019_constant_log_change_gdp_pc_log_change_NIFTY.pkl
# Training model 129: India_Weibull_2009_2020_constant_log_change_gdp_pc.pkl
# Training model 130: India_Weibull_2009_2020_constant_log_change_gdp_pc_log_change_NIFTY.pkl
# Training model 131: India_Weibull_2009_2021_constant_log_change_gdp_pc.pkl
# Training model 132: India_Weibull_2009_2021_constant_log_change_gdp_pc_log_change_NIFTY.pkl
# Training model 133: India_GeneralisedPareto_2009_2019_constant_log_change_gdp_pc.pkl
# Training model 134: India_GeneralisedPareto_2009_2019_constant_log_change_gdp_pc_log_change_NIFTY.pkl
# Training model 135: India_GeneralisedPareto_2009_2020_constant_log_change_gdp_pc.pkl
# Training model 136: India_GeneralisedPareto_2009_2020_constant_log_change_gdp_pc_log_change_NIFTY.pkl
# Training model 137: India_GeneralisedPareto_2009_2021_constant_log_change_gdp_pc.pkl
# Training model 138: India_GeneralisedPareto_2009_2021_constant_log_change_gdp_pc_log_change_NIFTY.pkl
# Training model 139: Israel + Turkey_Pareto_2010_2019_constant_log_change_gdp_pc.pkl
# Training model 140: Israel + Turkey_Pareto_2010_2019_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 141: Israel + Turkey_Pareto_2010_2020_constant_log_change_gdp_pc.pkl
# Training model 142: Israel + Turkey_Pareto_2010_2020_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 143: Israel + Turkey_Pareto_2010_2021_constant_log_change_gdp_pc.pkl
# Training model 144: Israel + Turkey_Pareto_2010_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 145: Israel + Turkey_Weibull_2010_2019_constant_log_change_gdp_pc.pkl
# Training model 146: Israel + Turkey_Weibull_2010_2019_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 147: Israel + Turkey_Weibull_2010_2020_constant_log_change_gdp_pc.pkl
# Training model 148: Israel + Turkey_Weibull_2010_2020_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 149: Israel + Turkey_Weibull_2010_2021_constant_log_change_gdp_pc.pkl
# Training model 150: Israel + Turkey_Weibull_2010_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 151: Israel + Turkey_GeneralisedPareto_2010_2019_constant_log_change_gdp_pc.pkl
# Training model 152: Israel + Turkey_GeneralisedPareto_2010_2019_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 153: Israel + Turkey_GeneralisedPareto_2010_2020_constant_log_change_gdp_pc.pkl
# Training model 154: Israel + Turkey_GeneralisedPareto_2010_2020_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 155: Israel + Turkey_GeneralisedPareto_2010_2021_constant_log_change_gdp_pc.pkl
# Training model 156: Israel + Turkey_GeneralisedPareto_2010_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 157: Italy_Pareto_2014_2021_constant_log_change_gdp_pc.pkl
# Training model 158: Italy_Pareto_2014_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 159: Italy_Weibull_2014_2021_constant_log_change_gdp_pc.pkl
# Training model 160: Italy_Weibull_2014_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 161: Italy_GeneralisedPareto_2014_2021_constant_log_change_gdp_pc.pkl
# Training model 162: Italy_GeneralisedPareto_2014_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 163: Japan_Pareto_2014_2021_constant_log_change_gdp_pc.pkl
# Training model 164: Japan_Pareto_2014_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 165: Japan_Weibull_2014_2021_constant_log_change_gdp_pc.pkl
# Training model 166: Japan_Weibull_2014_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 167: Japan_GeneralisedPareto_2014_2021_constant_log_change_gdp_pc.pkl
# Training model 168: Japan_GeneralisedPareto_2014_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 169: Russia_Pareto_2015_2021_constant_log_change_gdp_pc.pkl
# Training model 170: Russia_Pareto_2015_2021_constant_log_change_gdp_pc_log_change_MOEX.pkl
# Training model 171: Russia_Weibull_2015_2021_constant_log_change_gdp_pc.pkl
# Training model 172: Russia_Weibull_2015_2021_constant_log_change_gdp_pc_log_change_MOEX.pkl
# Training model 173: Russia_GeneralisedPareto_2015_2021_constant_log_change_gdp_pc.pkl
# Training model 174: Russia_GeneralisedPareto_2015_2021_constant_log_change_gdp_pc_log_change_MOEX.pkl
# Training model 175: Scandinavia_Pareto_2016_2021_constant_log_change_gdp_pc.pkl
# Training model 176: Scandinavia_Pareto_2016_2021_constant_log_change_gdp_pc_log_change_OMX40.pkl
# Training model 177: Scandinavia_Weibull_2016_2021_constant_log_change_gdp_pc.pkl
# Training model 178: Scandinavia_Weibull_2016_2021_constant_log_change_gdp_pc_log_change_OMX40.pkl
# Training model 179: Scandinavia_GeneralisedPareto_2016_2021_constant_log_change_gdp_pc.pkl
# Training model 180: Scandinavia_GeneralisedPareto_2016_2021_constant_log_change_gdp_pc_log_change_OMX40.pkl
# Training model 181: South Korea_Pareto_2015_2021_constant_log_change_gdp_pc.pkl
# Training model 182: South Korea_Pareto_2015_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 183: South Korea_Weibull_2015_2021_constant_log_change_gdp_pc.pkl
# Training model 184: South Korea_Weibull_2015_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 185: South Korea_GeneralisedPareto_2015_2021_constant_log_change_gdp_pc.pkl
# Training model 186: South Korea_GeneralisedPareto_2015_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 187: Southeast Asia_Pareto_2013_2021_constant_log_change_gdp_pc.pkl
# Training model 188: Southeast Asia_Pareto_2013_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 189: Southeast Asia_Weibull_2013_2021_constant_log_change_gdp_pc.pkl
# Training model 190: Southeast Asia_Weibull_2013_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 191: Southeast Asia_GeneralisedPareto_2013_2021_constant_log_change_gdp_pc.pkl
# Training model 192: Southeast Asia_GeneralisedPareto_2013_2021_constant_log_change_gdp_pc_log_change_MSCI.pkl
# Training model 193: U.S._Pareto_2005_2019_constant_log_change_gdp_pc.pkl
# Training model 194: U.S._Pareto_2005_2019_constant_log_change_gdp_pc_log_change_SPX.pkl
# Training model 195: U.S._Pareto_2005_2020_constant_log_change_gdp_pc.pkl
# Training model 196: U.S._Pareto_2005_2020_constant_log_change_gdp_pc_log_change_SPX.pkl
# Training model 197: U.S._Pareto_2005_2021_constant_log_change_gdp_pc.pkl
# Training model 198: U.S._Pareto_2005_2021_constant_log_change_gdp_pc_log_change_SPX.pkl
# Training model 199: U.S._Weibull_2005_2019_constant_log_change_gdp_pc.pkl
# Training model 200: U.S._Weibull_2005_2019_constant_log_change_gdp_pc_log_change_SPX.pkl
# Training model 201: U.S._Weibull_2005_2020_constant_log_change_gdp_pc.pkl
# Training model 202: U.S._Weibull_2005_2020_constant_log_change_gdp_pc_log_change_SPX.pkl
# Training model 203: U.S._Weibull_2005_2021_constant_log_change_gdp_pc.pkl
# Training model 204: U.S._Weibull_2005_2021_constant_log_change_gdp_pc_log_change_SPX.pkl
# Training model 205: U.S._GeneralisedPareto_2005_2019_constant_log_change_gdp_pc.pkl
# Training model 206: U.S._GeneralisedPareto_2005_2019_constant_log_change_gdp_pc_log_change_SPX.pkl
# Training model 207: U.S._GeneralisedPareto_2005_2020_constant_log_change_gdp_pc.pkl
# Training model 208: U.S._GeneralisedPareto_2005_2020_constant_log_change_gdp_pc_log_change_SPX.pkl
# Training model 209: U.S._GeneralisedPareto_2005_2021_constant_log_change_gdp_pc.pkl
# Training model 210: U.S._GeneralisedPareto_2005_2021_constant_log_change_gdp_pc_log_change_SPX.pkl
