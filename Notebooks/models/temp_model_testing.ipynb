# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pymc as pm
import arviz as az
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
from thesis_tools.utils.data import *
from thesis_tools.models.frequentist import *
from thesis_tools.models.bayesian_univariate_cross_sectional import *
from thesis_tools.models.bayesian_univariate_time_series import *

# %%
panel_df = read_panel_data(observations_threshold=50)
panel_df = panel_df[panel_df['group'] == 'U.S.']
y_data = np.array(panel_df[(panel_df['year'] == 2018) & (panel_df['group'] == 'U.S.')]['net_worth'].iloc[0])

# %%
# pareto_cs = Pareto_One_Stage(y_data=y_data)
# weibull_cs = Weibull_One_Stage(y_data=y_data)
# genpareto_cs = GeneralisedPareto_One_Stage(y_data=y_data)
pareto_ts = Univariate_Pareto_TimeSeries(panel_df=panel_df, train_until=2018, X_columns=['constant', 'log_change_gdp_pc', 'log_change_SPX'])
weibull_ts = Univariate_Weibull_TimeSeries(panel_df=panel_df, train_until=2018, X_columns=['constant', 'log_change_gdp_pc', 'log_change_SPX'])
genpareto_ts = Univariate_GeneralisedPareto_TimeSeries(panel_df=panel_df, train_until=2018, X_columns=['constant', 'log_change_gdp_pc', 'log_change_SPX'])
# Out:
# Panel is too long, truncating to 15 years
# Panel is too long, truncating to 15 years
# Panel is too long, truncating to 15 years

# %%
# pareto_cs.fit()
# weibull_cs.fit()
# genpareto_cs.fit()
# pareto_ts.fit()
weibull_ts.fit()
# genpareto_ts.fit()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta_variance_constant, beta_constant, beta_variance_log_change_gdp_pc, beta_log_change_gdp_pc, beta_variance_log_change_SPX, beta_log_change_SPX, gamma, alpha_2004, epsilon_sigma, epsilon_2005, epsilon_2006, epsilon_2007, epsilon_2008, epsilon_2009, epsilon_2010, epsilon_2011, epsilon_2012, epsilon_2013, epsilon_2014, epsilon_2015, epsilon_2016, epsilon_2017, epsilon_2018]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 815 seconds.
# There were 56 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details

# %%
weibull_ts.predict()
# Out:
#       alpha_2004  alpha_2005  alpha_2006  alpha_2007  alpha_2008  alpha_2009  \
# 0       0.923277    1.007465    1.052496    1.066477    1.125092    1.038963
# 1       1.007001    1.062296    1.086729    1.105023    1.145197    1.126296
# 2       0.960884    0.999818    1.033125    1.101822    1.077438    0.874930
# 3       1.013216    1.018436    1.039542    1.113192    1.148459    0.930709
# 4       0.996107    1.022109    1.082147    1.133970    1.127776    0.999065
# ...          ...         ...         ...         ...         ...         ...
# 7995    0.987562    1.000786    0.994643    1.058876    1.092833    1.038825
# 7996    0.970736    1.018422    1.083519    1.197536    1.203582    0.930651
# 7997    0.912175    0.963931    1.002769    1.070657    1.096127    0.955674
# 7998    0.928477    1.007514    1.137410    1.156358    1.209774    0.984828
# 7999    1.038953    0.984262    1.050249    1.157585    1.167496    0.966131
#
#       alpha_2010  alpha_2011  alpha_2012  alpha_2013  ...     y_2019  \
# 0       1.090376    1.139213    1.205728    1.304200  ...  10.794257
# 1       1.108142    1.188666    1.257486    1.281854  ...   1.595858
# 2       1.020639    1.136766    1.119181    1.218113  ...   7.908838
# 3       1.046365    1.126899    1.159749    1.282796  ...   1.175440
# 4       1.065367    1.163742    1.210502    1.257958  ...   1.795394
# ...          ...         ...         ...         ...  ...        ...
# 7995    1.147059    1.191691    1.200876    1.311822  ...   1.954803
# 7996    1.038402    1.155124    1.188536    1.251288  ...   2.228078
# 7997    1.090478    1.149900    1.206847    1.296249  ...   1.592107
# 7998    1.019618    1.115493    1.256633    1.291165  ...   5.025217
# 7999    1.072809    1.136739    1.122225    1.316382  ...   1.841691
#
#       epsilon_2020  alpha_2020     y_2020  epsilon_2021  alpha_2021  \
# 0         0.048316    1.922303   1.923308      0.009521    2.119323
# 1        -0.015993    1.664371   1.172961     -0.006249    1.719755
# 2         0.001922    1.773709   3.290810      0.027399    1.918247
# 3         0.026737    1.862256  19.651164      0.009783    1.924305
# 4        -0.037852    1.596141   7.928681      0.012993    1.696125
# ...            ...         ...        ...           ...         ...
# 7995     -0.017178    1.549738  14.327476      0.039572    1.669270
# 7996     -0.023037    1.705144   4.433748     -0.013577    1.807826
# 7997      0.003341    1.746060  17.208287      0.010563    1.907898
# 7998     -0.181410    1.540032   6.017907      0.029636    1.634435
# 7999      0.045504    1.754319   1.421508     -0.068175    1.836566
#
#          y_2021  epsilon_2022  alpha_2022    y_2022
# 0      2.393507      0.017302    2.351585  2.146897
# 1      2.086500     -0.038648    1.722983  1.363724
# 2      1.668084     -0.011790    2.051421  4.212584
# 3      1.967468     -0.010965    2.016827  1.249252
# 4      3.391771     -0.011214    1.788795  8.813892
# ...         ...           ...         ...       ...
# 7995   7.890273      0.050324    1.834310  1.004801
# 7996  29.977315     -0.028922    1.925489  6.800178
# 7997  11.582771     -0.012816    2.076757  2.638912
# 7998   8.025177     -0.035218    1.669647  2.313035
# 7999  15.964552      0.045608    2.155313  1.436358
#
# [8000 rows x 49 columns]
