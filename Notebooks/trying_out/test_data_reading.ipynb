# %%
import numpy as np
import pandas as pd

# %%
from thesis_tools.utils.data import *

# %%
read_panel_data()
# Out:
#     group  level_1  year        gdp_pc         MSCI          SPX  \
# 0    Alps     2449  2007  55761.563858  1515.400024  1438.239990
# 1    Alps     3131  2008  62809.830445  1486.400024  1378.550049
# 2    Alps     3929  2009  59594.137968   838.799988   825.880005
# 3    Alps     4602  2010  61400.490911  1119.500000  1073.869995
# 4    Alps     5530  2011  70551.454356  1331.699951  1286.119995
# ..    ...      ...   ...           ...          ...          ...
# 343  U.S.    17579  2019  65120.394663  2029.599976  2704.100098
# 344  U.S.    19550  2020  63528.634303  2342.399902  3225.520020
# 345  U.S.    21499  2021  70219.472454  2661.699951  3714.239990
# 346  U.S.    24074  2022  76329.582265  3052.500000  4515.549805
# 347  U.S.    26557  2023  76329.582265  2820.699951  4076.600098
#
#                                              net_worth  N_net_worth  \
# 0    [8.8, 5.5, 4.3, 3.6, 3.5, 3.4, 3.0, 2.7, 2.4, ...           10
# ...
