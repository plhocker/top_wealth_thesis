# %%
from thesis_tools.utils.data import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
region = "Central Eurasia"
year = "2022"
df_selfmade = read_billionaires_data(
    only_years=[year],
    only_regions=[region],
    self_made=True
)
df_inherited = read_billionaires_data(
    only_years=[year],
    only_regions=[region],
    self_made=False
)

# %%
df_selfmade
# Out:
#            year  rank  net_worth                  full_name  self_made  \
# 86   2022-01-01    87       18.4             Vladimir Lisin       True
# 96   2022-01-01    97       17.3           Vladimir Potanin       True
# 130  2022-01-01   130       14.0  Leonid Mikhelson & family       True
# 139  2022-01-01   138       13.2  Alexey Mordashov & family       True
# 160  2022-01-01   161       11.8            Mikhail Fridman       True
# ...         ...   ...        ...                        ...        ...
# 2567 2022-01-01  2448        1.1              Vlad Yatsenko       True
# 2571 2022-01-01  2448        1.1               Igor Yusufov       True
# 2610 2022-01-01  2578        1.0           Eugene Kaspersky       True
# 2614 2022-01-01  2578        1.0           Ihor Kolomoyskyy       True
# 2634 2022-01-01  2578        1.0            Boris Rotenberg       True
#
#      country_of_citizenship           region  log_net_worth
# 86                   Russia  Central Eurasia       2.912351
# 96                   Russia  Central Eurasia       2.850707
# 130                  Russia  Central Eurasia       2.639057
# 139                  Russia  Central Eurasia       2.580217
# 160                  Russia  Central Eurasia       2.468100
# ...                     ...              ...            ...
# 2567                Ukraine  Central Eurasia       0.095310
# 2571                 Russia  Central Eurasia       0.095310
# 2610                 Russia  Central Eurasia       0.000000
# 2614                Ukraine  Central Eurasia       0.000000
# 2634                 Russia  Central Eurasia       0.000000
#
# [92 rows x 8 columns]

# %%
# histogram
fig, ax = plt.subplots()
n_bins = 100
ax.hist(df_selfmade["net_worth"], bins=n_bins, alpha=0.5, label="Self-made")
ax.hist(df_inherited["net_worth"], bins=n_bins, alpha=0.5, label="Inherited")
ax.set_xlabel("Net worth")
ax.set_ylabel("Frequency")
# fit density
ax.legend()
plt.show()

# %%
# Fit density function
# Overlay KDE plot
fig, ax = plt.subplots()
sns.kdeplot(df_selfmade["net_worth"], label="Self-made", ax=ax)
sns.kdeplot(df_inherited["net_worth"], label="Inherited", ax=ax)
ax.set_xlabel("Net worth")
ax.set_ylabel("Density")
ax.legend()
plt.show()
# Out:
# /var/folders/3m/47824pgj6rl3wf7k8lbrkm_m0000gn/T/ipykernel_36536/2424648646.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df_inherited["net_worth"], label="Inherited", ax=ax)

# %%
# histogram
fig, ax = plt.subplots()
n_bins = 100
ax.hist(df_selfmade["log_net_worth"], bins=n_bins, alpha=0.5, label="Self-made")
ax.hist(df_inherited["log_net_worth"], bins=n_bins, alpha=0.5, label="Inherited")
ax.set_xlabel("Net worth")
ax.set_ylabel("Frequency")
# fit density
ax.legend()
plt.show()

# %%
# Fit density function
# Overlay KDE plot
fig, ax = plt.subplots()
sns.kdeplot(df_selfmade["log_net_worth"], label="Self-made", ax=ax)
sns.kdeplot(df_inherited["log_net_worth"], label="Inherited", ax=ax)
ax.set_xlabel("Net worth")
ax.set_ylabel("Density")
ax.legend()
plt.show()
# Out:
# /var/folders/3m/47824pgj6rl3wf7k8lbrkm_m0000gn/T/ipykernel_36536/114320903.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df_inherited["log_net_worth"], label="Inherited", ax=ax)
