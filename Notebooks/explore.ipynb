# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from thesis_tools.utils.data import *

# %%
df = read_billionaires_data()
# filter on region = Europe
# df = df[df['region'] == 'Europe']

# %%
len(df['full_name'].unique())
# Out:
# 4982

# %%
df
# Out:
#            year  rank  net_worth                              full_name  \
# 2    2022-01-01     3      158.0               Bernard Arnault & family
# 13   2022-01-01    14       74.8  Francoise Bettencourt Meyers & family
# 22   2022-01-01    23       59.6                         Amancio Ortega
# 27   2022-01-01    28       47.1                         Dieter Schwarz
# 30   2022-01-01    31       41.4                         Rodolphe Saadé
# ...         ...   ...        ...                                    ...
# 2623 2022-01-01  2578        1.0                           Adrian Paval
# 2633 2022-01-01  2578        1.0            Francisco Jose Riberas Mera
# 2637 2022-01-01  2578        1.0                          Oliver Samwer
# 2640 2022-01-01  2578        1.0                       Stephan Schnabel
# 2652 2022-01-01  2578        1.0                 Peter-Alexander Wacker
#
#       self_made country_of_citizenship  region  log_net_worth
# ...

# %%
df_selfmade = df[df['self_made'] == True]
df_inherited = df[df['self_made'] == False]

# %%
df_selfmade['log_net_worth'].hist(bins=100)
# Out:
# <Axes: >

# %%
df_inherited['log_net_worth'].hist(bins=100)
# Out:
# <Axes: >

# %%
df = pd.read_csv('../Data/socials/instagram_global_top_1000.csv')

# %%
df
# Out:
#     Country  Rank        Account                           Title  \
# 0       All     1      cristiano               Cristiano Ronaldo
# 1       All     2    kyliejenner                         Kylie 🤍
# 2       All     3       leomessi                       Leo Messi
# 3       All     4  kendalljenner                         Kendall
# 4       All     5    selenagomez                    Selena Gomez
# ..      ...   ...            ...                             ...
# 995     All   996  senoritasaeva                      Dina Saeva
# 996     All   997    manuelneuer                    Manuel Neuer
# 997     All   998      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998     All   999    mohanshakti                    Shakti Mohan
# 999     All  1000       eduincaz                       Eduin Caz
#
#                                          Link  \
# 0        https://www.instagram.com/cristiano/
# 1      https://www.instagram.com/kyliejenner/
# ...

# %%
np.log(df['Followers']).hist(bins=500)
# Out:
# <Axes: >
